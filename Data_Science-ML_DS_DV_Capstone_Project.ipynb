# %%
import pandas as pd

# %% [markdown]
# # Data Collection

# %%
dataset = pd.read_csv("Movie_Collection.csv") # reading the csv values and storing in the variable dataset

# %%
dataset
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %% [markdown]
# # Data Preprocessing Starts

# %%
dataset.isna() #finding for any null/missing values in the data set
# Out:
#      Marketing expense  Production expense  Multiplex coverage  Budget  \
# 0                False               False               False   False
# 1                False               False               False   False
# 2                False               False               False   False
# 3                False               False               False   False
# 4                False               False               False   False
# ..                 ...                 ...                 ...     ...
# 501              False               False               False   False
# 502              False               False               False   False
# 503              False               False               False   False
# 504              False               False               False   False
# 505              False               False               False   False
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
dataset.isnull().sum() #count of null/missing values column wise
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Start_Tech_Oscar        0
# dtype: int64

# %% [markdown]
# # Thumb Rule for Machine Learning and Data Science

# %%
# In the dataset, there should not be any missing values/empty/nan/null values
#-------Why did the NaN value came in the dataset, is there any relationship/logic else without any reason
#-------in the placement dataset the NaN value came whenever the student is not placed.
# Once missing/empty/nan/null values are resolved, need to check for outliers

# %% [markdown]
# ## Methods to replace missing values

# %%
#1) Replace the missing values with central tendancy (Mean, Median, Mode)
#2) Delete the entire row.
#3) Respective to the problem, have to replace the missing values with hard coded(standard) values. For our data set we need to replace it with 0 whic will not change the meaning or value.
#4) Consider this as a semi supervised, create a model, so that we can predict the missing values.

#For categorical data replacement
#1) Replace with mode
#2) Semi supervised - classification

#Incase of multiple columns NULL values replacement we need use "IMPUTATORS"

# %%
# In our dataset the NULL values are exists in the Time Taken column and also in the time taken column already 0 also exists. 
# So decided to replace the NULL values with 0 which will not impact the model creation processing. 
dataset["Time_taken"].fillna(0,inplace=True) #inplace=True means the changes directly applied into the dataset, not assigning to any variable.

# %%
dataset.isna().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# Start_Tech_Oscar       0
# dtype: int64

# %% [markdown]
# #  Data Science

# %%
# splitting the Quantitative and Qualitative Columns from the given dataset 
# Finding the Mean, Median, and Mode values for the given dataset(Measure of Central Tendency) 
# Finding IQR, 1.5rule, lesser outlier, and Greater outlier.

# %%
dataset.info() # displays the properties of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# Marketing expense      506 non-null float64
# Production expense     506 non-null float64
# Multiplex coverage     506 non-null float64
# Budget                 506 non-null float64
# Movie_length           506 non-null float64
# Lead_ Actor_Rating     506 non-null float64
# Lead_Actress_rating    506 non-null float64
# Director_rating        506 non-null float64
# Producer_rating        506 non-null float64
# Critic_rating          506 non-null float64
# Trailer_views          506 non-null int64
# 3D_available           506 non-null object
# Time_taken             506 non-null float64
# Twitter_hastags        506 non-null float64
# Genre                  506 non-null object
# Avg_age_actors         506 non-null int64
# Num_multiplex          506 non-null int64
# Collection             506 non-null int64
# Start_Tech_Oscar       506 non-null int64
# ...

# %%
#From the above output we can confirm below points
# There are 506 rows in the given dataset which starts 0 to 505
# There are 19 columns in the given dataset
# There are 12 float columns, 5 int column, 2 object columns
# All columns are having 506 values, but Time_Taken column has only 494 value. So Time_Taken column has 506-494 = 12 (NULL or NaN) value
# In the above statement we are doing dataset.info() after replacing the nan value with 0 thats why we are seeing 506 againist Time_Taken column
# If we use the same statement before the nan value replacement, we will see 494 as a value for the Time_Taken column.
# int = whole number , float = decimal value (continuous value) => Quantitative Column
# object = categorical value => Qualitative Column

# %% [markdown]
# #Splitting the Quan and Qual Columns
# ===================================
# #Quan = ["Marketing expense","Production expense","Multiplex coverage","Budget","Movie_length","Lead_ Actor_Rating","Lead_Actress_rating","Director_rating","Producer_rating","Critic_rating","Trailer_views","Time_taken","Twitter_hastags","Avg_age_actors","Num_multiplex","Collection","Start_Tech_Oscar"]
# #Qual = ["3D_available","Genre"]

# %%
dir(dataset) # to display all inbuild functions, from this we can use "dtypes" function for our task
# please go through all functions usage in w3 school for pandas
# Out:
# ['Avg_age_actors',
#  'Budget',
#  'Collection',
#  'Critic_rating',
#  'Director_rating',
#  'Genre',
#  'Lead_Actress_rating',
#  'Movie_length',
#  'Num_multiplex',
#  'Producer_rating',
#  'Start_Tech_Oscar',
#  'T',
#  'Time_taken',
#  'Trailer_views',
#  'Twitter_hastags',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
# ...

# %%
dataset.dtypes #displaying data type for each columns against to it in the data set
# Out:
# Marketing expense      float64
# Production expense     float64
# Multiplex coverage     float64
# Budget                 float64
# Movie_length           float64
# Lead_ Actor_Rating     float64
# Lead_Actress_rating    float64
# Director_rating        float64
# Producer_rating        float64
# Critic_rating          float64
# Trailer_views            int64
# 3D_available            object
# Time_taken             float64
# Twitter_hastags        float64
# Genre                   object
# Avg_age_actors           int64
# Num_multiplex            int64
# Collection               int64
# Start_Tech_Oscar         int64
# dtype: object

# %%
dataset["3D_available"].dtypes #displaying data type for 3D_available column ie 'O' => object
# Out:
# dtype('O')

# %%
dataset["Trailer_views"].dtypes #displaying data type for Trailer_views column ie 'int64' => whole number
# Out:
# dtype('int64')

# %%
dataset["Budget"].dtypes #displaying data type for Budget column ie 'float64' => continuous decimal value
# Out:
# dtype('float64')

# %%
#Creating empty list for Quantiative and Qualitative
Qual=[]
Quan=[]

# %%
def quanQual(p_dataset):  #standalone function can not be used outside this notebook
    p_Qual=[]
    p_Quan=[]
    for columnName in p_dataset.columns:
        #print(columnName)
        if(p_dataset[columnName].dtypes == 'O'):
            #print("Qual")
            p_Qual.append(columnName)
        else:
            #print("Quan")
            p_Quan.append(columnName)  
    return p_Quan, p_Qual # function can return 'n' number of values

# %%
quanQual(dataset)
# Out:
# (['Marketing expense',
#   'Production expense',
#   'Multiplex coverage',
#   'Budget',
#   'Movie_length',
#   'Lead_ Actor_Rating',
#   'Lead_Actress_rating',
#   'Director_rating',
#   'Producer_rating',
#   'Critic_rating',
#   'Trailer_views',
#   'Time_taken',
#   'Twitter_hastags',
#   'Avg_age_actors',
#   'Num_multiplex',
#   'Collection',
#   'Start_Tech_Oscar'],
#  ['3D_available', 'Genre'])

# %%
Quan, Qual=quanQual(dataset)

# %%
Quan
# Out:
# ['Marketing expense',
#  'Production expense',
#  'Multiplex coverage',
#  'Budget',
#  'Movie_length',
#  'Lead_ Actor_Rating',
#  'Lead_Actress_rating',
#  'Director_rating',
#  'Producer_rating',
#  'Critic_rating',
#  'Trailer_views',
#  'Time_taken',
#  'Twitter_hastags',
#  'Avg_age_actors',
#  'Num_multiplex',
#  'Collection',
#  'Start_Tech_Oscar']

# %%
Qual
# Out:
# ['3D_available', 'Genre']

# %% [markdown]
# ## Data Science
#
# ### Univariate Analysis
# Measure of Central Tendency - applicable for quantitative columns
# Measure of Location of Data - applicable for quantitative columns
# IQR - Inter Quartile Range
#
# ### Bivariate Analysis
# Covariance
# Correlation

# %%
import numpy as np # numpy library mostly used for calculation/statistical purpose

# %%
dir(np)
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'MachAr',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_NoValue',
#  '_UFUNC_API',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__doc__',
#  '__file__',
#  '__git_revision__',
#  '__loader__',
# ...

# %%
dataset.describe() # inbuild function to achieve basic DS
# Out:
#        Marketing expense  Production expense  Multiplex coverage  \
# count         506.000000          506.000000          506.000000
# mean           92.270471           77.273557            0.445305
# std           172.030902           13.720706            0.115878
# min            20.126400           55.920000            0.129000
# 25%            21.640900           65.380000            0.376000
# 50%            25.130200           74.380000            0.462000
# 75%            93.541650           91.200000            0.551000
# max          1799.524000          110.480000            0.615000
#
#              Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# count    506.000000    506.000000          506.000000           506.000000
# mean   34911.144022    142.074901            8.014002             8.185613
# std     3903.038232     28.148861            1.054266             1.054290
# min    19781.355000     76.400000            3.840000             4.035000
# ...

# %%
#Detailed Data Analysis 

MLD=pd.DataFrame(index=["Mean","Median","Mode","Min","Q1:25%","Q2:50%","Q3:75%","99%","Max","Q4:100%","IQR","1.5Rule","Lesser Outlier","Greater Outlier","Minimum","Maximum"],columns=Quan) # Table Creation with proper row and columns
for columnName in Quan:
    MLD[columnName]["Mean"]=dataset[columnName].mean() # considering outlier => finding avg for the given set
    MLD[columnName]["Median"]=dataset[columnName].median() # not considering outlier => finding mid term for the given set
    MLD[columnName]["Mode"]=dataset[columnName].mode()[0] # repeated value for the given set
    #From here MLD - PERCENTILE coding starts
    MLD[columnName]["Min"]=np.percentile(dataset[columnName],0)
    MLD[columnName]["Q1:25%"]=np.percentile(dataset[columnName],25)
    MLD[columnName]["Q2:50%"]=np.percentile(dataset[columnName],50)
    MLD[columnName]["Q3:75%"]=np.percentile(dataset[columnName],75)
    MLD[columnName]["99%"]=np.percentile(dataset[columnName],99)
    MLD[columnName]["Max"]=np.percentile(dataset[columnName],100)
    #From here IQR, 1.5rule, Lesser Outlier and Greater Outlier coding starts. 
    #IQR = Q3-Q1
    MLD[columnName]["IQR"]=MLD[columnName]["Q3:75%"]-MLD[columnName]["Q1:25%"]
    #1.5Rule = 1.5*IQR
    MLD[columnName]["1.5Rule"]=1.5*MLD[columnName]["IQR"]
    #Lesser Outlier = Q1-1.5*IQR
    MLD[columnName]["Lesser Outlier"]=MLD[columnName]["Q1:25%"]-MLD[columnName]["1.5Rule"]
    #Greater Outlier = Q3+1.5*IQR
    MLD[columnName]["Greater Outlier"]=MLD[columnName]["Q3:75%"]+MLD[columnName]["1.5Rule"]
    #Minimum
    MLD[columnName]["Minimum"]=dataset[columnName].min()
    #Maximum
    MLD[columnName]["Maximum"]=dataset[columnName].max()

# %%
MLD
# Out:
#                 Marketing expense Production expense Multiplex coverage  \
# Mean                      92.2705            77.2736           0.445305
# Median                    25.1302              74.38              0.462
# Mode                      20.3002               91.2              0.462
# Min                       20.1264              55.92              0.129
# Q1:25%                    21.6409              65.38              0.376
# Q2:50%                    25.1302              74.38              0.462
# Q3:75%                    93.5417               91.2              0.551
# 99%                       847.407              106.3              0.602
# Max                       1799.52             110.48              0.615
# Q4:100%                       NaN                NaN                NaN
# IQR                       71.9008              25.82              0.175
# 1.5Rule                   107.851              38.73             0.2625
# ...

# %% [markdown]
# # Finding Outlier Columns

# %%
#splitting lesser outlier columns and greater outlier columns in two different lists
lesser=[]
greater=[]

# %%
for columnName in Quan:
    if MLD[columnName]["Minimum"] < MLD[columnName]["Lesser Outlier"]: #logic to find lesser outlier columns in the dataframe
        lesser.append(columnName)
    if MLD[columnName]["Maximum"] > MLD[columnName]["Greater Outlier"]:  #logic to find greater outlier columns in the dataframe
        greater.append(columnName)

# %%
lesser
# Out:
# ['Budget',
#  'Lead_ Actor_Rating',
#  'Lead_Actress_rating',
#  'Director_rating',
#  'Producer_rating',
#  'Trailer_views',
#  'Time_taken',
#  'Collection']

# %%
greater
# Out:
# ['Marketing expense',
#  'Budget',
#  'Twitter_hastags',
#  'Num_multiplex',
#  'Collection']

# %% [markdown]
# # Replacing Outliers

# %%
for columnName in lesser:
    dataset[columnName][dataset[columnName]<MLD[columnName]["Lesser Outlier"]]=MLD[columnName]["Lesser Outlier"]
for columnName in greater:
    dataset[columnName][dataset[columnName]>MLD[columnName]["Greater Outlier"]]=MLD[columnName]["Greater Outlier"]
# Out:
# C:\Users\krish\Anaconda3\envs\krish_virtual\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\krish\Anaconda3\envs\krish_virtual\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\krish\Anaconda3\envs\krish_virtual\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Forming a DataFrame Post to Outlier Replacement
MLD=pd.DataFrame(index=["Mean","Median","Mode","Min","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5Rule","Lesser Outlier","Greater Outlier","Minimum","Maximum"],
                 columns=Quan) # Table Creation with proper row and columns
for columnName in Quan:
    MLD[columnName]["Mean"]=dataset[columnName].mean() # considering outlier => finding avg for the given set
    MLD[columnName]["Median"]=dataset[columnName].median() # not considering outlier => finding mid term for the given set
    MLD[columnName]["Mode"]=dataset[columnName].mode()[0] # repeated value for the given set
    #From here MLD - PERCENTILE coding starts
    MLD[columnName]["Min"]= dataset.describe()[columnName]["min"] #np.percentile(dataset[columnName],0)
    MLD[columnName]["Q1:25%"]= dataset.describe()[columnName]["25%"] #np.percentile(dataset[columnName],25)
    MLD[columnName]["Q2:50%"]= dataset.describe()[columnName]["50%"] #np.percentile(dataset[columnName],50)
    MLD[columnName]["Q3:75%"]= dataset.describe()[columnName]["75%"] #np.percentile(dataset[columnName],75)
    MLD[columnName]["Q4:100%"]= dataset.describe()[columnName]["max"] #np.percentile(dataset[columnName],100)
    #From here IQR, 1.5rule, Lesser Outlier and Greater Outlier coding starts. 
    #IQR = Q3-Q1
    MLD[columnName]["IQR"]=MLD[columnName]["Q3:75%"]-MLD[columnName]["Q1:25%"]
    #1.5Rule = 1.5*IQR
    MLD[columnName]["1.5Rule"]=1.5*MLD[columnName]["IQR"]
    #Lesser Outlier = Q1-1.5*IQR
    MLD[columnName]["Lesser Outlier"]=MLD[columnName]["Q1:25%"]-MLD[columnName]["1.5Rule"]
    #Greater Outlier = Q3+1.5*IQR
    MLD[columnName]["Greater Outlier"]=MLD[columnName]["Q3:75%"]+MLD[columnName]["1.5Rule"]
    #Minimum
    MLD[columnName]["Minimum"]=dataset[columnName].min()
    #Maximum
    MLD[columnName]["Maximum"]=dataset[columnName].max()

# %%
MLD
# Out:
#                 Marketing expense Production expense Multiplex coverage  \
# Mean                      64.5006            77.2736           0.445305
# Median                    25.1302              74.38              0.462
# Mode                      201.393               91.2              0.462
# Min                       20.1264              55.92              0.129
# Q1:25%                    21.6409              65.38              0.376
# Q2:50%                    25.1302              74.38              0.462
# Q3:75%                    93.5417               91.2              0.551
# Q4:100%                   201.393             110.48              0.615
# IQR                       71.9008              25.82              0.175
# 1.5Rule                   107.851              38.73             0.2625
# Lesser Outlier           -86.2102              26.65             0.1135
# Greater Outlier           201.393             129.93             0.8135
# ...

# %%
# Confirming no outlier exists
lesser1=[]
greater1=[]
for columnName in Quan:
    if MLD[columnName]["Minimum"] < MLD[columnName]["Lesser Outlier"]: #logic to find lesser outlier columns in the dataframe
        lesser1.append(columnName)
    if MLD[columnName]["Maximum"] > MLD[columnName]["Greater Outlier"]:  #logic to find greater outlier columns in the dataframe
        greater1.append(columnName)

# %%
lesser1
# Out:
# []

# %%
greater1
# Out:
# []

# %% [markdown]
# # Bivariate Analysis

# %%
dataset.cov() #automatically doing covariance between the quantitative columns
# Out:
#                      Marketing expense  Production expense  \
# Marketing expense         4.391324e+03          572.192782
# Production expense        5.721928e+02          188.257770
# Multiplex coverage       -5.094256e+00           -1.214147
# Budget                   -6.033336e+04       -19632.581233
# Movie_length              9.680205e+02          249.027806
# Lead_ Actor_Rating        3.823139e+01           10.116102
# Lead_Actress_rating       3.809556e+01           10.132500
# Director_rating           3.847995e+01           10.204324
# Producer_rating           3.746750e+01           10.052574
# Critic_rating            -1.076372e+01           -2.277047
# Trailer_views            -2.600531e+06      -552019.898337
# Time_taken               -6.139594e+01            5.953418
# Twitter_hastags           1.848697e+02           -9.096939
# Avg_age_actors            6.669849e+01            9.582362
# Num_multiplex             4.244957e+03         1030.712863
# ...

# %%
dataset.corr() #automatically doing correlation between the quantitative columns
# Out:
#                      Marketing expense  Production expense  \
# Marketing expense             1.000000            0.629315
# Production expense            0.629315            1.000000
# Multiplex coverage           -0.663412           -0.763651
# Budget                       -0.260057           -0.408704
# Movie_length                  0.518951            0.644779
# Lead_ Actor_Rating            0.556782            0.711541
# Lead_Actress_rating           0.555159            0.713151
# Director_rating               0.555796            0.711847
# Producer_rating               0.548873            0.711239
# Critic_rating                -0.246217           -0.251565
# Trailer_views                -0.582253           -0.596933
# Time_taken                   -0.027171            0.012725
# Twitter_hastags               0.081225           -0.019304
# Avg_age_actors                0.080433            0.055810
# Num_multiplex                 0.603966            0.708269
# ...
