# %%
# downloading important libraries
import pandas as pd
from sklearn.model_selection import train_test_split 
import time
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import pickle
import matplotlib.pyplot as plt

# %%
# Function
def split_scalar(indep_X,dep_Y):
        X_train, X_test, y_train, y_test = train_test_split(indep_X, dep_Y, test_size = 0.25, random_state = 0)
        #X_train, X_test, y_train, y_test = train_test_split(indep_X,dep_Y, test_size = 0.25, random_state = 0)
        
        #Feature Scaling
        #from sklearn.preprocessing import StandardScaler
        sc = StandardScaler()
        X_train = sc.fit_transform(X_train)
        X_test = sc.transform(X_test)    
        return X_train, X_test, y_train, y_test

# %%
# Function
def r2_prediction(regressor,X_test,y_test):
     y_pred = regressor.predict(X_test)
     from sklearn.metrics import r2_score
     r2=r2_score(y_test,y_pred)
     return r2

# %%
# Function
def Linear(X_train,y_train,X_test):       
        # Fitting K-NN to the Training set
        from sklearn.linear_model import LinearRegression
        regressor = LinearRegression()
        regressor.fit(X_train, y_train)
        r2=r2_prediction(regressor,X_test,y_test)
        return  r2

# %%
# Function
def svm_linear(X_train,y_train,X_test):
                
        from sklearn.svm import SVR
        regressor = SVR(kernel = 'linear')
        regressor.fit(X_train, y_train)
        r2=r2_prediction(regressor,X_test,y_test)
        return  r2

# %%
# Function
def svm_NL(X_train,y_train,X_test):
                
        from sklearn.svm import SVR
        regressor = SVR(kernel = 'rbf')
        regressor.fit(X_train, y_train)
        r2=r2_prediction(regressor,X_test,y_test)
        return  r2

# %%
# Function
def Decision(X_train,y_train,X_test):
        
        # Fitting K-NN to the Training setC
        from sklearn.tree import DecisionTreeRegressor
        regressor = DecisionTreeRegressor(random_state = 0)
        regressor.fit(X_train, y_train)
        r2=r2_prediction(regressor,X_test,y_test)
        return  r2

# %%
# Function
def random(X_train,y_train,X_test):       
        # Fitting K-NN to the Training set
        from sklearn.ensemble import RandomForestRegressor
        regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
        regressor.fit(X_train, y_train)
        r2=r2_prediction(regressor,X_test,y_test)
        return  r2

# %%
# Function: RFE (Recursive Feature Elimination)

from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

def rfeFeature(indep_X, dep_Y, n):
    """
    Performs Recursive Feature Elimination using multiple models.

    Parameters:
        indep_X (DataFrame): Feature set
        dep_Y (Series/array): Target variable
        n (int): Number of features to select

    Returns:
        list of dicts: Each dict contains model name, selected features, and transformed data
    """

    models = {
        "LinearRegression": LinearRegression(),
        "SVR_linear": SVR(kernel='linear'),
        "DecisionTree": DecisionTreeRegressor(random_state=0),
        "RandomForest": RandomForestRegressor(n_estimators=10, random_state=0)
    }

    results = []

    for name, model in models.items():
        print(f"\nRunning RFE with: {name}")

        rfe = RFE(estimator=model, n_features_to_select=n)
        fit = rfe.fit(indep_X, dep_Y)

        selected_features = list(indep_X.columns[fit.support_])

        # Convert directly to DataFrame
        X_selected = indep_X[selected_features]

        print("Selected Features:", selected_features)
        print("Shape:", X_selected.shape)

        results.append({
            "model": name,
            "features": selected_features,
            "X": X_selected
        })

    return results

# %%
# Function: To print the output in the table format
def rfe_regression(acclog,accsvml,accdes,accrf): 
    
    rfedataframe=pd.DataFrame(index=['Linear','SVC','Random','DecisionTree'],columns=['Linear','SVMl',
                                                                                        'Decision','Random'])

    for number,idex in enumerate(rfedataframe.index):
        
        rfedataframe['Linear'][idex]=acclog[number]       
        rfedataframe['SVMl'][idex]=accsvml[number]
        rfedataframe['Decision'][idex]=accdes[number]
        rfedataframe['Random'][idex]=accrf[number]
    return rfedataframe

# %%
dataset1=pd.read_csv("Movie_Collection.csv",index_col=None)

# %%
dataset1
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
df2=dataset1

df2 = pd.get_dummies(df2, drop_first=True)

# %%
df2
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
#Splitting input and output features
indep_X=df2.drop('Collection', 1) # removing the output column 'Collection' from the input set
dep_Y=df2['Collection'] # keeping only the output column 'Collection' in the output set

# %%
indep_X
indep_X.isna().values.any() # To confirm any NaN values exists in the dataset
indep_X.isna().sum() #Finding for which column how many NaN values are exist
indep_X['Time_taken'] = indep_X['Time_taken'].fillna(0) # Replacing the NaN value with 0
indep_X
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
dep_Y
# Out:
# 0      48000
# 1      43200
# 2      69400
# 3      66800
# 4      72400
#        ...
# 501    44800
# 502    41200
# 503    47800
# 504    44000
# 505    38000
# Name: Collection, Length: 506, dtype: int64

# %%
rfelist=rfeFeature(indep_X,dep_Y,3)       

acclin=[]
accsvml=[]
accsvmnl=[]
accdes=[]
accrf=[]
# Out:
# Running RFE with: LinearRegression
# Selected Features: ['Multiplex coverage', 'Lead_ Actor_Rating', 'Director_rating']
# Shape: (506, 3)
#
# Running RFE with: SVR_linear
# Selected Features: ['Production expense', 'Movie_length', 'Critic_rating']
# Shape: (506, 3)
#
# Running RFE with: DecisionTree
# Selected Features: ['Budget', 'Lead_Actress_rating', 'Trailer_views']
# Shape: (506, 3)
#
# Running RFE with: RandomForest
# Selected Features: ['Budget', 'Lead_Actress_rating', 'Trailer_views']
# Shape: (506, 3)

# %%
indep_X.isna().values.any() # To confirm any NaN values exists in the dataset
# Out:
# False

# %%
indep_X.isna().sum() #Finding for which column how many NaN values are exist
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# Time_taken             0
# Twitter_hastags        0
# Avg_age_actors         0
# Num_multiplex          0
# Start_Tech_Oscar       0
# 3D_available_YES       0
# Genre_Comedy           0
# Genre_Drama            0
# Genre_Thriller         0
# dtype: int64

# %%
(indep_X['Time_taken'] == 0).sum()
# Out:
# 14

# %%
indep_X['Time_taken'] = indep_X['Time_taken'].fillna(0) # Replacing the NaN value with 0

# %%
indep_X.isna().sum() # Confirming that no NaN values exist in the dataset
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# Time_taken             0
# Twitter_hastags        0
# Avg_age_actors         0
# Num_multiplex          0
# Start_Tech_Oscar       0
# 3D_available_YES       0
# Genre_Comedy           0
# Genre_Drama            0
# Genre_Thriller         0
# dtype: int64

# %%
dep_Y.isna().sum()
# Out:
# 0

# %%
"""
rfelist=rfeFeature(indep_X,dep_Y,6)       

acclin=[]
accsvml=[]
accsvmnl=[]
accdes=[]
accrf=[]

for i in rfelist:   
    X_train, X_test, y_train, y_test=split_scalar(i,dep_Y)  
    r2_lin=Linear(X_train,y_train,X_test)
    acclin.append(r2_lin)
    
    r2_sl=svm_linear(X_train,y_train,X_test)    
    accsvml.append(r2_sl)
    
    r2_NL=svm_NL(X_train,y_train,X_test)
    accsvmnl.append(r2_NL)
    
    r2_d=Decision(X_train,y_train,X_test)
    accdes.append(r2_d)
    
    r2_r=random(X_train,y_train,X_test)
    accrf.append(r2_r)
    
    
result=rfe_regression(acclin,accsvml,accdes,accrf)"""

rfelist = rfeFeature(indep_X, dep_Y, 5) #Considering 5 important features

for item in rfelist:
    X = item["X"]   # ✅ MUST extract like this

    X_train, X_test, y_train, y_test = split_scalar(X, dep_Y)

    r2_lin = Linear(X_train, y_train, X_test)
    acclin.append(r2_lin)

    r2_sl = svm_linear(X_train, y_train, X_test)
    accsvml.append(r2_sl)

    r2_NL = svm_NL(X_train, y_train, X_test)
    accsvmnl.append(r2_NL)

    r2_d = Decision(X_train, y_train, X_test)
    accdes.append(r2_d)

    r2_r = random(X_train, y_train, X_test)
    accrf.append(r2_r)
# Out:
# Running RFE with: LinearRegression
# Selected Features: ['Multiplex coverage', 'Lead_ Actor_Rating', 'Director_rating', 'Critic_rating', 'Start_Tech_Oscar']
# Shape: (506, 5)
#
# Running RFE with: SVR_linear
# Selected Features: ['Production expense', 'Movie_length', 'Director_rating', 'Producer_rating', 'Critic_rating']
# Shape: (506, 5)
#
# Running RFE with: DecisionTree
# Selected Features: ['Marketing expense', 'Multiplex coverage', 'Budget', 'Lead_Actress_rating', 'Trailer_views']
# Shape: (506, 5)
#
# Running RFE with: RandomForest
# Selected Features: ['Marketing expense', 'Multiplex coverage', 'Budget', 'Lead_Actress_rating', 'Trailer_views']
# Shape: (506, 5)
